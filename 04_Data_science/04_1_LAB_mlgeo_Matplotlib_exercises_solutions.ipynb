# %% [markdown]
# # ___
#
# # [ Machine Learning in Geosciences ]
#
# **Department of Applied Geoinformatics and Carthography, Charles University**
#
# *Lukas Brodsky lukas.brodsky@natur.cuni.cz*

# %% [markdown]
# ## Matplotlib exercises
#
# 1. line plotting
#
# 2. scaterplot and line ploting
#
# 3. histogram plotting
#
# 4. multiplot (two functions)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **Exercise 1:** line plot
# * Plot line graph with plt.plot() method using x and y1 and y2 data
# * Plot sin with blue line and cosfunction with green dashed line
# * Add plot label and legend

# %%
# Sample data
import numpy as np
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x, y1, 'b-') 
plt.plot(x, y2, 'g--') 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Plotting sin and cos functions')
# plt.legend(loc="best")
# Out:
# Text(0.5, 1.0, 'Plotting sin and cos functions')

# %% [markdown]
# ### **Exercise 2:**  scatterplot and line together
#
# * Combine `plt.scatterplot()` and `plt.plot()`.
#
# * Use scatterplot for x and y1 samples; and lineplot for x and y2 for the 'underlying function'.
#
# * Add legend

# %%
# Data
N = 50
x = np.linspace(0., 10., N)
y1 = np.sin(x)**2 + np.cos(x) + np.random.randn(N) / 10
y2 = np.sin(x)**2 + np.cos(x)

# %%
plt.scatter(x, y1, edgecolor="b", s=20, label="xy samples")
plt.plot(x, y2, color="green", linestyle="dashed", label="Underlying function")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc="best")

# %% [markdown]
# ### **Exercise 3:**  histogram
#
# * Plot histogram of `z` values

# %%
# data
z = np.random.randn(1000)

# %%
# histogram 
plt.hist(z)
# Out:
# (array([  2.,  15.,  60., 144., 240., 241., 186.,  81.,  24.,   7.]),
#  array([-3.45209254, -2.78417292, -2.1162533 , -1.44833368, -0.78041405,
#         -0.11249443,  0.55542519,  1.22334481,  1.89126443,  2.55918405,
#          3.22710367]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Exercise 3: multiplot
#
# * Use subplot: nrows=1, ncols=2 to create the multiplot.
#
# * Plot (x,y) and (x,z) on the axes of 2 plot side by side.

# %%
# data 
x = np.arange(0,6)
y = x*2
z = x**2

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'bo-') 
plt.subplot(1,2,2)
plt.plot(x, z, 'g*-');
